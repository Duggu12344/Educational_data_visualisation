# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install matplotlib
# !pip3 install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#functions to return multiple data
      #indian Education statistics
def data_info_1():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/IndianEducationStatistics (1).csv')
      #facilities
def data_info_2():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/electricity-availability.csv')
def data_info_3():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/computer-availability.csv')
def data_info_4():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/internet-facility.csv')
def data_info_5():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/library-facility.csv')
      #dropout and enrollment
def data_info_6():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/gross-enrollment-ratio-2013-2016.csv')
def data_info_7():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/dropout-ratio-2012-2015.csv')
      #Teachers and courses
def data_info_8():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/number-of-teachers.csv')
def data_info_9():
  return pd.read_csv(r'/home/msit-desktop-pc/Desktop/project/vocational-courses-taken.csv')
                                             #-----xxxx------#

# %%
#function for indian education statictics
def statistics_bar_vs_year():
  data1 = data_info_1()
  plt.figure(figsize=(15,15))
  plt.subplot(3,3,1)
  sns.barplot(x='year', y='U_Primary_With_Sec_HrSec', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper primary with HS(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,2)
  sns.barplot(x='year', y='Sec_with_HrSec.', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Higher secondary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,3)
  sns.barplot(x='year', y='U_Primary_Only', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,4)
  sns.barplot(x='year', y='HrSec_Only', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Higher secondary only(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,5)
  sns.barplot(x='year', y='U_Primary_With_Sec', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper primary with secomdary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,6)
  sns.barplot(x='year', y='Primary_with_U_Primary_Sec', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper and lower primary with section(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,7)
  sns.barplot(x='year', y='Primary_with_U_Primary_Sec_HrSec', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper and lower primary with hr_sec(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,8)
  sns.barplot(x='year', y='Primary_Only', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Only primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,9)
  sns.barplot(x='year', y='Primary_with_U_Primary', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper and lower primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.tight_layout()

# statistics_bar_vs_year()
def statistics_bar_vs_state():
  data = data_info_1()
  column_name = 'State_UT'
  d_no_sme_state = data.drop_duplicates(subset=column_name)
  d_no_sme_state.to_csv('data1.csv', index=False)
  data1 = pd.read_csv('data1.csv')
  plt.figure(figsize=(25,25))
  plt.subplot(3,3,1)
  sns.barplot(x='State_UT', y='U_Primary_With_Sec_HrSec', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper primary with HS(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,2)
  sns.barplot(x='State_UT', y='Sec_with_HrSec.', data=data1)
  plt.title('Barplot')
  plt.xlabel('State')
  plt.ylabel('Higher secondary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,3)
  sns.barplot(x='State_UT', y='U_Primary_Only', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,4)
  sns.barplot(x='State_UT', y='HrSec_Only', data=data1)
  plt.xlabel('State')
  plt.ylabel('Higher secondary only(% of students)')
  plt.xticks(rotation='vertical')
  plt.title('Barplot')
  plt.subplot(3,3,5)
  sns.barplot(x='State_UT', y='U_Primary_With_Sec', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper primary with secomdary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,6)
  sns.barplot(x='State_UT', y='Primary_with_U_Primary_Sec', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper and lower primary with section(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,7)
  sns.barplot(x='State_UT', y='Primary_with_U_Primary_Sec_HrSec', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper and lower primary with hr_sec(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,8)
  sns.barplot(x='State_UT', y='Primary_Only', data=data1)
  plt.xlabel('State')
  plt.ylabel('Only primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,9)
  sns.barplot(x='State_UT', y='Primary_with_U_Primary', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper and lower primary(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.tight_layout()
# statistics_bar_vs_state()
def statistics_comparison_state():
  data = data_info_1()
  column_name = 'State_UT'
  d_no_sme_state = data.drop_duplicates(subset=column_name)
  d_no_sme_state.to_csv('data1.csv', index=False)
  data1_1 = pd.read_csv('data1.csv')
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State_UT'], data1_1['HrSec_Only'],label='HS students', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State_UT'], data1_1['Primary_Only'], label='Primary students', marker='s', linestyle='--',color='r')
  plt.title('Multiline plot between state with primary and higher secondary schools')
  plt.xlabel('States')
  plt.ylabel('Schools(% of students)')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State_UT'], data1_1['Primary_with_U_Primary_Sec'],label='Primary with secondary', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State_UT'], data1_1['HrSec_Only'], label='Higher secondary', marker='s', linestyle='--',color='green')
  plt.title('Multiline plot between state with primary with secondary and higher secondary schools')
  plt.xlabel('States')
  plt.ylabel('Schools(% of students)')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State_UT'], data1_1['U_Primary_Only'],label='Upper primary', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State_UT'], data1_1['Primary_Only'], label='Primary', marker='s', linestyle='--',color='yellow')
  plt.title('Multiline plot between state with upper primary and primary schools')
  plt.xlabel('States')
  plt.ylabel('Schools(% of students)')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State_UT'], data1_1['HrSec_Only'],label='HS students', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State_UT'], data1_1['All Schools'], label='All students', marker='s', linestyle='--',color='purple')
  plt.title('Multiline plot between state with Higher secondary and all schools')
  plt.xlabel('States')
  plt.ylabel('Schools(% of students)')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# statistics_comparison_state()
def statistics_plot():
  data1 = data_info_1()
  column_name = 'State_UT'
  d_no_sme_state = data1.drop_duplicates(subset=column_name)
  d_no_sme_state.to_csv('data1.csv', index=False)
  data = pd.read_csv('data1.csv')
  plt.figure(figsize=(8, 8))
  category_counts = data['U_Primary_Only'].value_counts()
  plt.pie(category_counts, labels=category_counts.index, startangle=140)
  plt.title('State-wise distribution of Upper primary students')
  plt.show()
  plt.tight_layout()
  sns.scatterplot(x='State_UT', y='U_Primary_Only', data = data)
  plt.title('Scatter plot b/w state and upper primary school')
  plt.xticks(rotation='vertical')
  plt.show()
  plt.tight_layout()
  plt.figure(figsize=(8,8))
  plt.plot(data['State_UT'], data['All Schools'], marker='o', linestyle='-',color='b')
  plt.title('Line plot of all schools with states')
  plt.xlabel('States')
  plt.ylabel('All schools(% of Students)')
  plt.xticks(rotation='vertical')
  plt.grid(True)
  data.plot.hist()
  plt.tight_layout()
  plt.figure(figsize=(8,8))
  heatmap_data = data.pivot(index='State_UT', columns='All Schools', values='All Schools')
  sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt=".2f", linewidths=.1)
  plt.title('Thermal Map(Heatmap)')
  plt.show()
  plt.tight_layout()
  plt.figure(figsize=(8,8))
  sns.boxplot(x='State_UT', y='HrSec_Only', data=data1)
  plt.title('Boxplot between percentage of students of higher secondary vs state')
  plt.xlabel('States')
  plt.ylabel('Students of higher secondary(% of students)')
  plt.xticks(rotation='vertical')
  plt.show()
  plt.tight_layout()
# statistics_plot()

# %%
#functions of facilities
def electricity_bar_vs_state():
  data1 = data_info_2()
  plt.figure(figsize=(25,25))
  plt.title('Availability of electricity')
  plt.subplot(3,3,1)
  sns.barplot(x='State', y='Total Schools - All Management', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,2)
  sns.barplot(x='State', y='Total Schools - Govt.', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,3)
  sns.barplot(x='State', y='Total Schools - Govt. Aided', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,4)
  sns.barplot(x='State', y='Total Schools - Pvt. unaided', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,5)
  sns.barplot(x='State', y='Total Schools - Others', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,6)
  sns.barplot(x='State', y='Schools with Electricity Facility - All Management', data=data1)
  plt.xlabel('State')
  plt.ylabel('Upper and lower primary with section(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,7)
  sns.barplot(x='State', y='Schools with Electricity Facility - Govt. Aided', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,8)
  sns.barplot(x='State', y='Schools with Electricity Facility - Pvt. unaided', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,9)
  sns.barplot(x='State', y='% of Schools with Electricity Connection - All Management', data=data1)
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.tight_layout()
# electricity_bar_vs_state()
def electricity_comparison():
  data1_1 = data_info_2()
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State'], data1_1['Total Schools - All Management'],label='Total schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Electricity Facility - All Management'], label='Electricity available', marker='s', linestyle='--',color='r')
  plt.title('Total school')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt. Aided'],label='Govt aided schools', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State'], data1_1['Schools with Electricity Facility - Govt. Aided'], label='Electricity available', marker='s', linestyle='--',color='green')
  plt.title('Govt aided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State'], data1_1['Total Schools - Pvt. unaided'],label='Private schools', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State'], data1_1['Schools with Electricity Facility - Pvt. unaided'], label='Electricity available', marker='s', linestyle='--',color='yellow')
  plt.title('Multiline plot between state with upper primary and primary schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt.'],label='Total govt schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Electricity Facility - Govt.'], label='Electricity available', marker='s', linestyle='--',color='pink')
  plt.title('Multiline plot between state with Higher secondary and all schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# electricity_comparison()
def computer_availability_comparison():
  data1_1 = data_info_3()
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State'], data1_1['Total Schools - All Management'],label='Total schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Computer Facility - All Management'], label='Computer available', marker='s', linestyle='--',color='r')
  plt.title('Total school')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt. Aided'],label='Govt aided schools', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State'], data1_1['Schools with Computer Facility - Govt. Aided'], label='Computer available', marker='s', linestyle='--',color='green')
  plt.title('Govt aided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State'], data1_1['Total Schools - Pvt. Unaided'],label='Private schools', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State'], data1_1['Schools with Computer Facility - Pvt. Unaided'], label='Computer available', marker='s', linestyle='--',color='yellow')
  plt.title('Pvt unaided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt.'],label='Total govt schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Computer Facility - Govt.'], label='Computer available', marker='s', linestyle='--',color='purple')
  plt.title('Govt schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# computer_availability_comparison()
def internet_availability_comparison():
  data1_1 = data_info_4()
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State'], data1_1['Total Schools - All Management'],label='Total schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Internet Facility Available - All Management'], label='Internet available', marker='s', linestyle='--',color='r')
  plt.title('Total school')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt. Aided'],label='Govt aided schools', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State'], data1_1['Schools with Internet Facility Available - Govt. Aided'], label='Internet available', marker='s', linestyle='--',color='green')
  plt.title('Govt aided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State'], data1_1['Total Schools - Pvt. Unaided'],label='Private schools', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State'], data1_1['Schools with Internet Facility Available - Pvt. Unaided'], label='Internet available', marker='s', linestyle='--',color='yellow')
  plt.title('Pvt unaided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt.'],label='Total govt schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Internet Facility Available - Govt. Aided'], label='Internet available', marker='s', linestyle='--',color='purple')
  plt.title('Govt schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# internet_availability_comparison()
def library_availability_comparison():
  data1_1 = data_info_5()
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State'], data1_1['Total Schools - All Management'],label='Total schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Library Facility - All Management'], label='Library available', marker='s', linestyle='--',color='r')
  plt.title('Total school')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt. Aided'],label='Govt aided schools', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State'], data1_1['Schools with Library Facility - Govt. Aided'], label='Library available', marker='s', linestyle='--',color='green')
  plt.title('Govt aided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State'], data1_1['Total Schools - Pvt. Unaided'],label='Private schools', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State'], data1_1['Schools with Library Facility - Pvt. Unaided'], label='Library available', marker='s', linestyle='--',color='yellow')
  plt.title('Pvt unaided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State'], data1_1['Total Schools - Govt.'],label='Total govt schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Schools with Library Facility - Govt. Aided'], label='Library available', marker='s', linestyle='--',color='purple')
  plt.title('Govt schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# library_availability_comparison()

# %%
#dropout and enrollment
def dropout():
  data1 = data_info_6()
  plt.figure(figsize=(15,15))
  plt.subplot(3,3,1)
  sns.barplot(x='Year', y='Primary_Boys', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Primary_Boys(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,2)
  sns.barplot(x='Year', y='Primary_Girls', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Primary_Girls(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,3)
  sns.barplot(x='Year', y='Primary_Total', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Primary_Total(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,4)
  sns.barplot(x='Year', y='Upper_Primary_Boys', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper_Primary_Boys(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,5)
  sns.barplot(x='Year', y='Upper_Primary_Total', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Upper_Primary_Total(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,6)
  sns.barplot(x='Year', y='Secondary_Boys', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Secondary_Boys(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,7)
  sns.barplot(x='Year', y='Secondary_Girls', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Secondary_Girls(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,8)
  sns.barplot(x='Year', y='Secondary_Total', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Secondary_Total(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.subplot(3,3,9)
  sns.barplot(x='Year', y='Secondary_Total', data=data1)
  plt.xlabel('Year')
  plt.ylabel('Higher_Secondary_Girls(% of students)')
  plt.title('Barplot')
  plt.xticks(rotation='vertical')
  plt.tight_layout()
dropout()
def enrollment():
  data2 = data_info_7()
  column_name = 'State_UT'
  data2 = data2.head(20)
  plt.figure(figsize=(15, 15))
  plt.subplot(2,2,1)
  sns.scatterplot(x='State_UT', y='Primary_Total', data=data2)
  plt.title('Scatter map for total primary students(dropout ratio)')
  plt.xticks(rotation='vertical')
  plt.subplot(2,2,2)
  sns.scatterplot(x='State_UT', y='Upper Primary_Total', data=data2)
  plt.title('Scatter map for total upper primary students(dropout ratio)')
  plt.xticks(rotation='vertical')
  plt.subplot(2,2,3)
  sns.scatterplot(x='State_UT', y='Secondary _Total', data=data2)
  plt.title('Scatter map for total secondary students')
  plt.xticks(rotation='vertical')
  plt.subplot(2,2,4)
  sns.scatterplot(x='State_UT', y='HrSecondary_Total', data=data2)
  plt.title('Scatter map for total higher secondary students')
  plt.xticks(rotation='vertical')
  plt.tight_layout()
# enrollment()

# %%
#teachers and cources
def teachers():
  data = data_info_8()
  plt.figure(figsize=(15, 15))
  plt.subplot(2, 2, 1)
  sns.barplot(x='State', y='Number of Teachers by Gender and Classes Taught - All Types of Management - Total - Male', data=data)
  plt.title('Female secondary teachers')
  plt.xlabel('State')
  plt.ylabel('Male teachers')
  plt.xticks(rotation='vertical')
  plt.subplot(2, 2, 2)
  sns.barplot(x='State', y='Number of Teachers by Gender and Classes Taught - All Types of Management - Total - Female', data=data)
  plt.title('Male secondary teachers')
  plt.xlabel('State')
  plt.ylabel('Female teachers')
  plt.xticks(rotation='vertical')
  plt.subplot(2, 2, 3)
  sns.barplot(x='State', y='Number of Teachers by Gender and Classes Taught - All Types of Management - Total - Total', data=data)
  plt.title('All secondary teachers')
  plt.xlabel('State')
  plt.ylabel('All teachers')
  plt.xticks(rotation='vertical')
  plt.subplot(2, 2, 4)
  sns.barplot(x='State', y='Number of Teachers by Gender and Classes Taught - All Types of Management - Pre-Primary Only - Male', data=data)
  plt.title('All primary teachers')
  plt.xlabel('State')
  plt.ylabel('Pre-primary male teachers')
  plt.xticks(rotation='vertical')
  plt.tight_layout()
# teachers()
def courses():
  data1_1 = data_info_9()
  plt.figure(figsize=(20, 20))
  plt.subplot(2, 2, 1)
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools - All Management'],label='Total schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools Having Vocational Courses under NSQF at Secondary/ Higher Secondary Level - All Management'], label='Courses available', marker='s', linestyle='--',color='r')
  plt.title('Total school')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 2)
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools - Govt.'],label='Govt schools', marker='o', linestyle='-',color='black')
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools Having Vocational Courses under NSQF at Secondary/ Higher Secondary Level - Govt.'], label='Courses available', marker='s', linestyle='--',color='green')
  plt.title('Govt schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 3)
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools - Govt. Aided'],label='Govt aided schools', marker='o', linestyle='-',color='brown')
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools Having Vocational Courses under NSQF at Secondary/ Higher Secondary Level - Govt. Aided'], label='Courses available', marker='s', linestyle='--',color='yellow')
  plt.title('Govt aided')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.subplot(2, 2, 4)
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools - Pvt. Unaided'],label='Total govt schools', marker='o', linestyle='-',color='b')
  plt.plot(data1_1['State'], data1_1['Number of Secondary and Higher Secondary Schools Having Vocational Courses under NSQF at Secondary/ Higher Secondary Level - Pvt. Unaided'], label='Courses available', marker='s', linestyle='--',color='purple')
  plt.title('Govt aided schools')
  plt.xlabel('States')
  plt.ylabel('Schools')
  plt.legend()
  plt.grid(True)
  plt.xticks(rotation='vertical')
  plt.plot()
  plt.tight_layout()
# courses()

# %%
print("<----Welcome to Data visualisation---->")
while True:
  choice = int(input("Enter your choice-->\n(1)--> Educational statistics\n(2)--> Educational facilities\n(3)--> Enrolled and dropout students\n(4)--> Teachers and courses\n(5)--> Exit\n"))
  while True:
    if(choice == 1 or choice == 2 or choice == 3 or choice == 4 or choice == 5):
      break
    else:
      print(f'{choice} is not a valid choice..!\nEnter again--> ')
  if(choice == 1):
    while True:
      choice1 = int(input("What kind of plot do you want..?\n(1)--> Bar plot with year\n(2)--> Bar plot with state\n(3)--> Comparison with state\n(4)--> Other plots "))
      if(choice1 == 1 or choice1 == 2 or choice1 == 3 or choice1 == 4):
        break
      else:
        print(f'{choice1} is not a valid choice..!\nEnter again--> ')
    if(choice1 == 1):
      statistics_bar_vs_year()
    elif(choice1 == 2):
      statistics_bar_vs_state()
    elif(choice1 == 3):
      statistics_comparison_state()
    elif(choice1 == 4):
      statistics_plot()
  elif(choice == 2):
    while True:
      choice1 = int(input("Enter the facility:--> \n(1)--> Electricity\n(2)--> Computer\n(3)--> Internet\n(4)--> Library\n"))
      if(choice1 == 1 or choice1 == 2 or choice1 == 3 or choice1 == 4):
        break
      else:
        print(f'{choice1} is not a valid choice..!\nEnter again\n')
    if(choice1 == 1):
      while True:
        choice2 = int(input("Enter your choice-->\n(1)--> Bar graph with state\n(2)--> Comparison\n"))
        if(choice2 == 1 or choice2 == 2):
          break
        else:
          print(f"{choice2} is not a valid choice..!\nEnter again \n")
      if(choice2 == 1):
        electricity_bar_vs_state()
      elif(choice2 == 2):
        electricity_comparison()
    elif(choice1 == 2):
      computer_availability_comparison()
    elif(choice1 == 3):
      internet_availability_comparison()
    elif(choice1 == 4):
      library_availability_comparison()
  elif(choice == 3):
    while True:
      choice1 = int(input("Enter your choice:-->\n(1)--> Numbers of enrollment\n(2)--> Dropout ratio/n"))
      if(choice1 == 1 or choice1 == 2):
        break
      else:
        print(f'{choice1} is not a valid choice..!\nEnter again \n')
    if(choice1 == 1):
      enrollment()
    elif(choice1 == 2):
      dropout()
  elif(choice == 4):
    while True:
      choice1 = int(input("Enter your choice:-->\n(1)--> Comparison between teachers\n(2)--> Courses \n"))
      if(choice1 == 1 or choice1 == 2):
        break
      else:
        print(f'{choice1} is not a valid choice..!\nEnter again...\n')
    if(choice1 == 1):
      teachers()
    else:
      courses()
  elif(choice == 5):
    break
# Out:
# <----Welcome to Data visualisation---->
